# %%
import blankly
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.nn import LSTM
import torch.optim as optim
from torch.autograd import Variable

# %%
def episode_gen(data, seq_length,output_size):
    x = []
    y = []
    #Loop through data, adding input data to x array and output data to y array
    for i in range(len(data)-seq_length):
        _x = data[i:(i+seq_length - output_size)]
        _y = data[i+seq_length - output_size:i + seq_length]
        x.append(_x)
        y.append(_y)

    return np.array(x),np.array(y)

# %%
def init_NN(symbol, state: blankly.StrategyState):
    interface = state.interface
    resolution = state.resolution
    variables = state.variables

    #Get price data
    variables['history'] = interface.history(symbol, 300, resolution, return_as='list')['close']
    rsi = blankly.indicators.rsi(state.variables['history'])
    macd = blankly.indicators.macd(state.variables['history'])

    seq_length = 8
    output_size = 3

    x = [variables['history'][i] / variables['history'][i-1] for i in range(25,len(variables['history']))]
    x, y = episode_gen(x, seq_length, output_size)
    y = Variable(torch.Tensor(np.array(y))).unsqueeze(0)
    #RSI data gathering
    x_rsi = rsi[11:]
    x_rsi,_ = episode_gen(x_rsi,seq_length, output_size)

    #MACD data gathering
    macd_vals,_ = episode_gen(macd[0], seq_length, output_size)
    macd_signals,_ = episode_gen(macd[1],seq_length, output_size)

    x_agg = np.zeros((len(macd_signals),seq_length-output_size, 4))
    for i in range(len(macd_signals)):
      for j in range(seq_length - output_size):
        x_agg[i][j][0] = x[i][j]
        x_agg[i][j][1] = x_rsi[i][j]
        x_agg[i][j][2] = macd_vals[i][j]
        x_agg[i][j][3] = macd_signals[i][j]
    x_tot = Variable(torch.Tensor(x_agg))
    
    #begin training
    num_epochs = 10000
    learning_rate = 0.0003


    state.lstm = LSTM(4,20, batch_first = True)
    state.lin = nn.Linear(20,3)
    criterion = torch.nn.MSELoss()    
    optimizer = torch.optim.Adam([
                {'params': state.lstm.parameters()},
                {'params': state.lin.parameters()}
            ], lr=learning_rate)

    # Train the model
    for epoch in range(num_epochs):
        #run model
        outputs, (h_n, c_n) = state.lstm(x_tot)
        out = state.lin(h_n)
        out = 0.5 + F.sigmoid(out)
        optimizer.zero_grad()
        
        loss = criterion(out, y) 
        
        loss.backward() 
        
        optimizer.step() 

        if epoch % 500 == 0:
          print("Epoch: %d, loss: %1.5f" % (epoch, loss.item()))
    
    state.lastthree = [[0,0],[0,0],[0,0]]

# %%
def price_lstm(price,symbol,state: blankly.StrategyState):
    state.variables['history'].append(price) #Add latest price to current list of data

    into = [state.variables['history'][i]/state.variables['history'][i-1] for i in range(-5,0)]
    rsi = blankly.indicators.rsi(state.variables['history'])
    rsi_in = np.array(rsi[-5:])
    macd = blankly.indicators.macd(state.variables['history'])
    macd_vals = np.array(macd[0][-5:])
    macd_signals = np.array(macd[1][-5:])

    
    pred_in = np.zeros((1,len(into),4))
    for i in range(len(into)):
      pred_in[0][i][0] = into[i]
      pred_in[0][i][1] = rsi_in[i]
      pred_in[0][i][2] = macd_vals[i]
      pred_in[0][i][3] = macd_signals[i]
    pred_in = torch.Tensor(pred_in)
  
    print(price)

   
    out,(h,c) = state.lstm(pred_in)
    out = state.lin(h)
    out = 0.5 + F.sigmoid(out)
    
   
    state.lastthree[0][0]+=out[0][0][0]
    state.lastthree[0][1]+=1
    state.lastthree[1][0]+=out[0][0][1]
    state.lastthree[1][1]+=1
    state.lastthree[2][0]+=out[0][0][2]
    state.lastthree[2][1]+=1

    
    priceavg = state.lastthree[0][0]/state.lastthree[0][1]

    curr_value = blankly.trunc(state.interface.account[state.base_asset].available, 2)
    if priceavg > 1:
        buy = blankly.trunc(state.interface.cash  * 2 * (priceavg.item() - 1)/price, 2) 
        if buy > 0:
          state.interface.market_order(symbol, side='buy', size=buy)
    elif curr_value > 0:
         cv =  blankly.trunc(curr_value  * 2 * (1 - priceavg.item()),2)
         if cv > 0:
          state.interface.market_order(symbol, side='sell', size=cv)

    print("prediction for price --",priceavg)
    state.lastthree = [state.lastthree[1], state.lastthree[2], [0,0]]

# %%
exchange = blankly.Alpaca() #Connect to API
strategy = blankly.Strategy(exchange) #Initialize a Blankly strategy
strategy.add_price_event(price_lstm, symbol='AAPL', resolution='1d', init=init_NN)
results = strategy.backtest(to='1y', initial_values={'USD': 10000}) #Backtest one year starting with $10,000
print(results)
# Out:
# INFO: No portfolio name to load specified, defaulting to the first in the file: (another cool portfolio). This is fine if there is only one portfolio in use.
# No cached data found for AAPL from: 1683944667.2364469 to 1715394267.236473 at a resolution of 86400 seconds.
#
# Backtesting...
# Epoch: 0, loss: 0.00243
# Epoch: 500, loss: 0.00041
# Epoch: 1000, loss: 0.00038
# Epoch: 1500, loss: 0.00036
# Epoch: 2000, loss: 0.00033
# Epoch: 2500, loss: 0.00030
# Epoch: 3000, loss: 0.00026
# Epoch: 3500, loss: 0.00022
# Epoch: 4000, loss: 0.00019
# Epoch: 4500, loss: 0.00017
# Epoch: 5000, loss: 0.00016
# Epoch: 5500, loss: 0.00015
# Epoch: 6000, loss: 0.00015
# Epoch: 6500, loss: 0.00014
# Epoch: 7000, loss: 0.00014
# Epoch: 7500, loss: 0.00013
# Epoch: 8000, loss: 0.00013
# Epoch: 8500, loss: 0.00013
# Epoch: 9000, loss: 0.00012
# Epoch: 9500, loss: 0.00012
# 172.07
# prediction for price -- tensor(1.0027, grad_fn=<DivBackward0>)
# 172.07
# prediction for price -- tensor(1.0072, grad_fn=<DivBackward0>)
# 172.07
# prediction for price -- tensor(1.0068, grad_fn=<DivBackward0>)
# 172.07
# prediction for price -- tensor(1.0098, grad_fn=<DivBackward0>)
# 172.69
# prediction for price -- tensor(1.0101, grad_fn=<DivBackward0>)
# 175.05
# prediction for price -- tensor(1.0063, grad_fn=<DivBackward0>)
# 175.16
# prediction for price -- tensor(1.0021, grad_fn=<DivBackward0>)
# 174.2
# prediction for price -- tensor(1.0000, grad_fn=<DivBackward0>)
# 174.2
# prediction for price -- tensor(0.9986, grad_fn=<DivBackward0>)
# 174.2
# prediction for price -- tensor(1.0002, grad_fn=<DivBackward0>)
# 171.56
# prediction for price -- tensor(1.0074, grad_fn=<DivBackward0>)
# 171.84
# prediction for price -- tensor(1.0159, grad_fn=<DivBackward0>)
# 172.99
# prediction for price -- tensor(1.0136, grad_fn=<DivBackward0>)
# 175.43
# prediction for price -- tensor(1.0151, grad_fn=<DivBackward0>)
# 177.3
# prediction for price -- tensor(1.0094, grad_fn=<DivBackward0>)
# 177.3
# prediction for price -- tensor(1.0011, grad_fn=<DivBackward0>)
# 177.3
# prediction for price -- tensor(0.9948, grad_fn=<DivBackward0>)
# 177.3
# prediction for price -- tensor(0.9958, grad_fn=<DivBackward0>)
# 177.25
# prediction for price -- tensor(1.0005, grad_fn=<DivBackward0>)
# 180.09
# prediction for price -- tensor(1.0017, grad_fn=<DivBackward0>)
# 180.95
# prediction for price -- tensor(1.0003, grad_fn=<DivBackward0>)
# 179.58
# prediction for price -- tensor(0.9993, grad_fn=<DivBackward0>)
# 179.58
# prediction for price -- tensor(0.9973, grad_fn=<DivBackward0>)
# 179.58
# prediction for price -- tensor(0.9992, grad_fn=<DivBackward0>)
# 179.21
# prediction for price -- tensor(1.0039, grad_fn=<DivBackward0>)
# 177.82
# prediction for price -- tensor(1.0069, grad_fn=<DivBackward0>)
# 180.57
# prediction for price -- tensor(1.0068, grad_fn=<DivBackward0>)
# 180.96
# prediction for price -- tensor(1.0048, grad_fn=<DivBackward0>)
# 183.79
# prediction for price -- tensor(1.0043, grad_fn=<DivBackward0>)
# 183.79
# prediction for price -- tensor(0.9969, grad_fn=<DivBackward0>)
# 183.79
# prediction for price -- tensor(0.9928, grad_fn=<DivBackward0>)
# 183.31
# prediction for price -- tensor(0.9923, grad_fn=<DivBackward0>)
# 183.95
# prediction for price -- tensor(0.9946, grad_fn=<DivBackward0>)
# 186.01
# prediction for price -- tensor(0.9953, grad_fn=<DivBackward0>)
# 184.92
# prediction for price -- tensor(0.9963, grad_fn=<DivBackward0>)
# 185.01
# prediction for price -- tensor(0.9947, grad_fn=<DivBackward0>)
# 185.01
# prediction for price -- tensor(0.9939, grad_fn=<DivBackward0>)
# 185.01
# prediction for price -- tensor(0.9962, grad_fn=<DivBackward0>)
# 185.01
# prediction for price -- tensor(0.9969, grad_fn=<DivBackward0>)
# 183.96
# prediction for price -- tensor(0.9977, grad_fn=<DivBackward0>)
# 187.0
# prediction for price -- tensor(0.9967, grad_fn=<DivBackward0>)
# 186.68
# prediction for price -- tensor(0.9964, grad_fn=<DivBackward0>)
# 185.27
# prediction for price -- tensor(0.9993, grad_fn=<DivBackward0>)
# 185.27
# prediction for price -- tensor(0.9988, grad_fn=<DivBackward0>)
# 185.27
# prediction for price -- tensor(1.0009, grad_fn=<DivBackward0>)
# 188.06
# prediction for price -- tensor(1.0046, grad_fn=<DivBackward0>)
# 189.25
# prediction for price -- tensor(1.0023, grad_fn=<DivBackward0>)
# 189.59
# prediction for price -- tensor(0.9977, grad_fn=<DivBackward0>)
# 193.97
# prediction for price -- tensor(0.9905, grad_fn=<DivBackward0>)
# 192.46
# prediction for price -- tensor(0.9909, grad_fn=<DivBackward0>)
# 192.46
# prediction for price -- tensor(0.9912, grad_fn=<DivBackward0>)
# 192.46
# prediction for price -- tensor(0.9921, grad_fn=<DivBackward0>)
# 191.33
# prediction for price -- tensor(0.9959, grad_fn=<DivBackward0>)
# 191.33
# prediction for price -- tensor(0.9978, grad_fn=<DivBackward0>)
# 191.81
# prediction for price -- tensor(0.9984, grad_fn=<DivBackward0>)
# 190.68
# prediction for price -- tensor(1.0009, grad_fn=<DivBackward0>)
# 188.61
# prediction for price -- tensor(1.0060, grad_fn=<DivBackward0>)
# 188.61
# prediction for price -- tensor(1.0119, grad_fn=<DivBackward0>)
# 188.61
# prediction for price -- tensor(1.0155, grad_fn=<DivBackward0>)
# 188.08
# prediction for price -- tensor(1.0241, grad_fn=<DivBackward0>)
# 189.77
# prediction for price -- tensor(1.0232, grad_fn=<DivBackward0>)
# 190.54
# prediction for price -- tensor(1.0124, grad_fn=<DivBackward0>)
# 190.69
# prediction for price -- tensor(1.0108, grad_fn=<DivBackward0>)
# 193.99
# prediction for price -- tensor(1.0013, grad_fn=<DivBackward0>)
# 193.99
# prediction for price -- tensor(0.9967, grad_fn=<DivBackward0>)
# 193.99
# prediction for price -- tensor(0.9995, grad_fn=<DivBackward0>)
# 193.73
# prediction for price -- tensor(1.0004, grad_fn=<DivBackward0>)
# 195.1
# prediction for price -- tensor(1.0053, grad_fn=<DivBackward0>)
# 193.13
# prediction for price -- tensor(1.0096, grad_fn=<DivBackward0>)
# 191.94
# prediction for price -- tensor(1.0143, grad_fn=<DivBackward0>)
# 192.75
# prediction for price -- tensor(1.0153, grad_fn=<DivBackward0>)
# 192.75
# prediction for price -- tensor(1.0194, grad_fn=<DivBackward0>)
# 192.75
# prediction for price -- tensor(1.0206, grad_fn=<DivBackward0>)
# 193.62
# prediction for price -- tensor(1.0139, grad_fn=<DivBackward0>)
# 194.5
# prediction for price -- tensor(1.0093, grad_fn=<DivBackward0>)
# 193.22
# prediction for price -- tensor(1.0096, grad_fn=<DivBackward0>)
# 195.83
# prediction for price -- tensor(1.0091, grad_fn=<DivBackward0>)
# 196.45
# prediction for price -- tensor(1.0065, grad_fn=<DivBackward0>)
# 196.45
# prediction for price -- tensor(1.0108, grad_fn=<DivBackward0>)
# 196.45
# prediction for price -- tensor(1.0072, grad_fn=<DivBackward0>)
# 195.605
# prediction for price -- tensor(1.0101, grad_fn=<DivBackward0>)
# 192.58
# prediction for price -- tensor(1.0169, grad_fn=<DivBackward0>)
# 191.17
# prediction for price -- tensor(1.0290, grad_fn=<DivBackward0>)
# 181.99
# prediction for price -- tensor(1.0523, grad_fn=<DivBackward0>)
# 178.85
# prediction for price -- tensor(1.0545, grad_fn=<DivBackward0>)
# 178.85
# prediction for price -- tensor(0.9932, grad_fn=<DivBackward0>)
# 178.85
# prediction for price -- tensor(1.0681, grad_fn=<DivBackward0>)
# 179.8
# prediction for price -- tensor(1.0013, grad_fn=<DivBackward0>)
# 178.19
# prediction for price -- tensor(1.0167, grad_fn=<DivBackward0>)
# 177.97
# prediction for price -- tensor(0.9700, grad_fn=<DivBackward0>)
# 177.79
# prediction for price -- tensor(0.9317, grad_fn=<DivBackward0>)
# 179.46
# prediction for price -- tensor(0.9423, grad_fn=<DivBackward0>)
# 179.46
# prediction for price -- tensor(0.9610, grad_fn=<DivBackward0>)
# 179.46
# prediction for price -- tensor(0.9699, grad_fn=<DivBackward0>)
# 177.45
# prediction for price -- tensor(0.9515, grad_fn=<DivBackward0>)
# 176.57
# prediction for price -- tensor(1.0075, grad_fn=<DivBackward0>)
# 174.0
# prediction for price -- tensor(0.9998, grad_fn=<DivBackward0>)
# 174.49
# prediction for price -- tensor(1.0124, grad_fn=<DivBackward0>)
# 175.84
# prediction for price -- tensor(1.0175, grad_fn=<DivBackward0>)
# 175.84
# prediction for price -- tensor(1.0452, grad_fn=<DivBackward0>)
# 175.84
# prediction for price -- tensor(0.9729, grad_fn=<DivBackward0>)
# 177.23
# prediction for price -- tensor(0.9125, grad_fn=<DivBackward0>)
# 181.12
# prediction for price -- tensor(0.9463, grad_fn=<DivBackward0>)
# 176.38
# prediction for price -- tensor(0.9979, grad_fn=<DivBackward0>)
# 178.61
# prediction for price -- tensor(0.9374, grad_fn=<DivBackward0>)
# 180.19
# prediction for price -- tensor(0.9994, grad_fn=<DivBackward0>)
# 180.19
# prediction for price -- tensor(0.9895, grad_fn=<DivBackward0>)
# 180.19
# prediction for price -- tensor(0.9841, grad_fn=<DivBackward0>)
# 184.12
# prediction for price -- tensor(1.0069, grad_fn=<DivBackward0>)
# 187.65
# prediction for price -- tensor(1.0207, grad_fn=<DivBackward0>)
# 187.87
# prediction for price -- tensor(1.0089, grad_fn=<DivBackward0>)
# 189.46
# prediction for price -- tensor(1.0111, grad_fn=<DivBackward0>)
# 189.7
# prediction for price -- tensor(1.0146, grad_fn=<DivBackward0>)
# 189.7
# prediction for price -- tensor(1.0158, grad_fn=<DivBackward0>)
# 189.7
# prediction for price -- tensor(1.0166, grad_fn=<DivBackward0>)
# 189.7
# prediction for price -- tensor(1.0199, grad_fn=<DivBackward0>)
# 182.91
# prediction for price -- tensor(1.0234, grad_fn=<DivBackward0>)
# 177.56
# prediction for price -- tensor(1.0390, grad_fn=<DivBackward0>)
# 178.18
# prediction for price -- tensor(1.0587, grad_fn=<DivBackward0>)
# 179.36
# prediction for price -- tensor(1.0414, grad_fn=<DivBackward0>)
# 179.36
# prediction for price -- tensor(1.0332, grad_fn=<DivBackward0>)
# 179.36
# prediction for price -- tensor(1.0332, grad_fn=<DivBackward0>)
# 176.3
# prediction for price -- tensor(1.0070, grad_fn=<DivBackward0>)
# 174.21
# prediction for price -- tensor(0.9994, grad_fn=<DivBackward0>)
# 175.74
# prediction for price -- tensor(1.0362, grad_fn=<DivBackward0>)
# 175.01
# prediction for price -- tensor(1.0525, grad_fn=<DivBackward0>)
# 177.97
# prediction for price -- tensor(1.0312, grad_fn=<DivBackward0>)
# 177.97
# prediction for price -- tensor(0.9696, grad_fn=<DivBackward0>)
# 177.97
# prediction for price -- tensor(0.9973, grad_fn=<DivBackward0>)
# 179.07
# prediction for price -- tensor(1.0008, grad_fn=<DivBackward0>)
# 175.49
# prediction for price -- tensor(1.0149, grad_fn=<DivBackward0>)
# 173.93
# prediction for price -- tensor(0.9909, grad_fn=<DivBackward0>)
# 174.79
# prediction for price -- tensor(0.9865, grad_fn=<DivBackward0>)
# 176.08
# prediction for price -- tensor(0.9908, grad_fn=<DivBackward0>)
# 176.08
# prediction for price -- tensor(0.9849, grad_fn=<DivBackward0>)
# 176.08
# prediction for price -- tensor(0.9866, grad_fn=<DivBackward0>)
# 171.96
# prediction for price -- tensor(1.0102, grad_fn=<DivBackward0>)
# 170.43
# prediction for price -- tensor(0.9945, grad_fn=<DivBackward0>)
# 170.69
# prediction for price -- tensor(0.9584, grad_fn=<DivBackward0>)
# 171.21
# prediction for price -- tensor(0.9284, grad_fn=<DivBackward0>)
# 173.75
# prediction for price -- tensor(0.9747, grad_fn=<DivBackward0>)
# 173.75
# prediction for price -- tensor(0.9665, grad_fn=<DivBackward0>)
# 173.75
# prediction for price -- tensor(0.9411, grad_fn=<DivBackward0>)
# 172.4
# prediction for price -- tensor(0.9627, grad_fn=<DivBackward0>)
# 173.66
# prediction for price -- tensor(0.9845, grad_fn=<DivBackward0>)
# 174.91
# prediction for price -- tensor(0.9917, grad_fn=<DivBackward0>)
# 177.49
# prediction for price -- tensor(1.0025, grad_fn=<DivBackward0>)
# 178.99
# prediction for price -- tensor(1.0120, grad_fn=<DivBackward0>)
# 178.99
# prediction for price -- tensor(0.9926, grad_fn=<DivBackward0>)
# 178.99
# prediction for price -- tensor(1.0137, grad_fn=<DivBackward0>)
# 178.39
# prediction for price -- tensor(1.0156, grad_fn=<DivBackward0>)
# 179.8
# prediction for price -- tensor(1.0172, grad_fn=<DivBackward0>)
# 180.71
# prediction for price -- tensor(1.0143, grad_fn=<DivBackward0>)
# 178.85
# prediction for price -- tensor(1.0123, grad_fn=<DivBackward0>)
# 178.72
# prediction for price -- tensor(1.0152, grad_fn=<DivBackward0>)
# 178.72
# prediction for price -- tensor(1.0180, grad_fn=<DivBackward0>)
# 178.72
# prediction for price -- tensor(1.0194, grad_fn=<DivBackward0>)
# 177.15
# prediction for price -- tensor(1.0141, grad_fn=<DivBackward0>)
# 175.84
# prediction for price -- tensor(1.0153, grad_fn=<DivBackward0>)
# 175.46
# prediction for price -- tensor(1.0154, grad_fn=<DivBackward0>)
# 172.88
# prediction for price -- tensor(1.0101, grad_fn=<DivBackward0>)
# 173.0
# prediction for price -- tensor(0.9977, grad_fn=<DivBackward0>)
# 173.0
# prediction for price -- tensor(0.9731, grad_fn=<DivBackward0>)
# 173.0
# prediction for price -- tensor(1.0359, grad_fn=<DivBackward0>)
# 173.44
# prediction for price -- tensor(1.0765, grad_fn=<DivBackward0>)
# 171.1
# prediction for price -- tensor(1.0633, grad_fn=<DivBackward0>)
# 166.89
# prediction for price -- tensor(1.0684, grad_fn=<DivBackward0>)
# 168.22
# prediction for price -- tensor(1.0051, grad_fn=<DivBackward0>)
# 170.29
# prediction for price -- tensor(0.9603, grad_fn=<DivBackward0>)
# 170.29
# prediction for price -- tensor(1.0058, grad_fn=<DivBackward0>)
# 170.29
# prediction for price -- tensor(0.9494, grad_fn=<DivBackward0>)
# 170.77
# prediction for price -- tensor(0.9576, grad_fn=<DivBackward0>)
# 173.97
# prediction for price -- tensor(0.9474, grad_fn=<DivBackward0>)
# 177.57
# prediction for price -- tensor(0.9646, grad_fn=<DivBackward0>)
# 176.65
# prediction for price -- tensor(1.0005, grad_fn=<DivBackward0>)
# 179.23
# prediction for price -- tensor(0.9894, grad_fn=<DivBackward0>)
# 179.23
# prediction for price -- tensor(1.0164, grad_fn=<DivBackward0>)
# 179.23
# prediction for price -- tensor(1.0188, grad_fn=<DivBackward0>)
# 181.82
# prediction for price -- tensor(1.0176, grad_fn=<DivBackward0>)
# 182.89
# prediction for price -- tensor(1.0185, grad_fn=<DivBackward0>)
# 182.41
# prediction for price -- tensor(1.0190, grad_fn=<DivBackward0>)
# 186.4
# prediction for price -- tensor(1.0192, grad_fn=<DivBackward0>)
# 184.8
# prediction for price -- tensor(1.0206, grad_fn=<DivBackward0>)
# 184.8
# prediction for price -- tensor(1.0207, grad_fn=<DivBackward0>)
# 184.8
# prediction for price -- tensor(1.0181, grad_fn=<DivBackward0>)
# 187.44
# prediction for price -- tensor(1.0169, grad_fn=<DivBackward0>)
# 188.01
# prediction for price -- tensor(1.0111, grad_fn=<DivBackward0>)
# 189.71
# prediction for price -- tensor(1.0036, grad_fn=<DivBackward0>)
# 189.69
# prediction for price -- tensor(0.9973, grad_fn=<DivBackward0>)
# 191.45
# prediction for price -- tensor(0.9936, grad_fn=<DivBackward0>)
# 191.45
# prediction for price -- tensor(0.9909, grad_fn=<DivBackward0>)
# 191.45
# prediction for price -- tensor(0.9885, grad_fn=<DivBackward0>)
# 190.64
# prediction for price -- tensor(0.9869, grad_fn=<DivBackward0>)
# 191.31
# prediction for price -- tensor(0.9855, grad_fn=<DivBackward0>)
# 189.97
# prediction for price -- tensor(0.9857, grad_fn=<DivBackward0>)
# 189.97
# prediction for price -- tensor(0.9864, grad_fn=<DivBackward0>)
# 189.79
# prediction for price -- tensor(0.9864, grad_fn=<DivBackward0>)
# 189.79
# prediction for price -- tensor(0.9861, grad_fn=<DivBackward0>)
# 189.79
# prediction for price -- tensor(0.9855, grad_fn=<DivBackward0>)
# 190.4
# prediction for price -- tensor(0.9841, grad_fn=<DivBackward0>)
# 189.37
# prediction for price -- tensor(0.9848, grad_fn=<DivBackward0>)
# 189.95
# prediction for price -- tensor(0.9870, grad_fn=<DivBackward0>)
# 191.24
# prediction for price -- tensor(0.9875, grad_fn=<DivBackward0>)
# 189.43
# prediction for price -- tensor(0.9922, grad_fn=<DivBackward0>)
# 189.43
# prediction for price -- tensor(0.9983, grad_fn=<DivBackward0>)
# 189.43
# prediction for price -- tensor(0.9993, grad_fn=<DivBackward0>)
# 193.42
# prediction for price -- tensor(1.0020, grad_fn=<DivBackward0>)
# 192.32
# prediction for price -- tensor(1.0020, grad_fn=<DivBackward0>)
# 194.27
# prediction for price -- tensor(0.9993, grad_fn=<DivBackward0>)
# 195.71
# prediction for price -- tensor(0.9910, grad_fn=<DivBackward0>)
# 193.18
# prediction for price -- tensor(0.9966, grad_fn=<DivBackward0>)
# 193.18
# prediction for price -- tensor(1.0006, grad_fn=<DivBackward0>)
# 193.18
# prediction for price -- tensor(1.0036, grad_fn=<DivBackward0>)
# 194.71
# prediction for price -- tensor(1.0101, grad_fn=<DivBackward0>)
# 197.96
# prediction for price -- tensor(1.0073, grad_fn=<DivBackward0>)
# 198.11
# prediction for price -- tensor(1.0015, grad_fn=<DivBackward0>)
# 197.57
# prediction for price -- tensor(0.9960, grad_fn=<DivBackward0>)
# 195.89
# prediction for price -- tensor(0.9958, grad_fn=<DivBackward0>)
# 195.89
# prediction for price -- tensor(1.0013, grad_fn=<DivBackward0>)
# 195.89
# prediction for price -- tensor(1.0071, grad_fn=<DivBackward0>)
# 196.94
# prediction for price -- tensor(1.0112, grad_fn=<DivBackward0>)
# 194.83
# prediction for price -- tensor(1.0120, grad_fn=<DivBackward0>)
# 194.68
# prediction for price -- tensor(1.0146, grad_fn=<DivBackward0>)
# 193.6
# prediction for price -- tensor(1.0150, grad_fn=<DivBackward0>)
# 193.05
# prediction for price -- tensor(1.0263, grad_fn=<DivBackward0>)
# 193.05
# prediction for price -- tensor(1.0281, grad_fn=<DivBackward0>)
# 193.05
# prediction for price -- tensor(1.0261, grad_fn=<DivBackward0>)
# 193.05
# prediction for price -- tensor(1.0232, grad_fn=<DivBackward0>)
# 193.15
# prediction for price -- tensor(1.0163, grad_fn=<DivBackward0>)
# 193.58
# prediction for price -- tensor(1.0085, grad_fn=<DivBackward0>)
# 192.53
# prediction for price -- tensor(1.0027, grad_fn=<DivBackward0>)
# 185.64
# prediction for price -- tensor(1.0150, grad_fn=<DivBackward0>)
# 185.64
# prediction for price -- tensor(1.0114, grad_fn=<DivBackward0>)
# 185.64
# prediction for price -- tensor(0.9657, grad_fn=<DivBackward0>)
# 185.64
# prediction for price -- tensor(1.0845, grad_fn=<DivBackward0>)
# 184.25
# prediction for price -- tensor(1.0047, grad_fn=<DivBackward0>)
# 181.91
# prediction for price -- tensor(0.9780, grad_fn=<DivBackward0>)
# 181.18
# prediction for price -- tensor(0.9697, grad_fn=<DivBackward0>)
# 185.56
# prediction for price -- tensor(0.9964, grad_fn=<DivBackward0>)
# 185.56
# prediction for price -- tensor(1.0217, grad_fn=<DivBackward0>)
# 185.56
# prediction for price -- tensor(0.9653, grad_fn=<DivBackward0>)
# 185.14
# prediction for price -- tensor(0.9332, grad_fn=<DivBackward0>)
# 186.19
# prediction for price -- tensor(0.9426, grad_fn=<DivBackward0>)
# 185.59
# prediction for price -- tensor(0.9360, grad_fn=<DivBackward0>)
# 185.92
# prediction for price -- tensor(0.9532, grad_fn=<DivBackward0>)
# 183.63
# prediction for price -- tensor(0.9673, grad_fn=<DivBackward0>)
# 183.63
# prediction for price -- tensor(0.9773, grad_fn=<DivBackward0>)
# 183.63
# prediction for price -- tensor(0.9603, grad_fn=<DivBackward0>)
# 183.63
# prediction for price -- tensor(0.9355, grad_fn=<DivBackward0>)
# 182.68
# prediction for price -- tensor(0.9411, grad_fn=<DivBackward0>)
# 188.63
# prediction for price -- tensor(0.9582, grad_fn=<DivBackward0>)
# 191.56
# prediction for price -- tensor(0.9578, grad_fn=<DivBackward0>)
# 193.89
# prediction for price -- tensor(0.9519, grad_fn=<DivBackward0>)
# 193.89
# prediction for price -- tensor(0.9771, grad_fn=<DivBackward0>)
# 193.89
# prediction for price -- tensor(1.0278, grad_fn=<DivBackward0>)
# 195.18
# prediction for price -- tensor(1.0215, grad_fn=<DivBackward0>)
# 194.5
# prediction for price -- tensor(1.0245, grad_fn=<DivBackward0>)
# 194.17
# prediction for price -- tensor(1.0257, grad_fn=<DivBackward0>)
# 192.42
# prediction for price -- tensor(1.0271, grad_fn=<DivBackward0>)
# 191.73
# prediction for price -- tensor(1.0317, grad_fn=<DivBackward0>)
# 191.73
# prediction for price -- tensor(1.0327, grad_fn=<DivBackward0>)
# 191.73
# prediction for price -- tensor(1.0312, grad_fn=<DivBackward0>)
# 188.04
# prediction for price -- tensor(1.0267, grad_fn=<DivBackward0>)
# 184.4
# prediction for price -- tensor(1.0396, grad_fn=<DivBackward0>)
# 186.86
# prediction for price -- tensor(1.0372, grad_fn=<DivBackward0>)
# 185.85
# prediction for price -- tensor(1.0001, grad_fn=<DivBackward0>)
# 187.68
# prediction for price -- tensor(1.0278, grad_fn=<DivBackward0>)
# 187.68
# prediction for price -- tensor(1.0174, grad_fn=<DivBackward0>)
# 187.68
# prediction for price -- tensor(0.9768, grad_fn=<DivBackward0>)
# 189.3
# prediction for price -- tensor(0.9725, grad_fn=<DivBackward0>)
# 189.41
# prediction for price -- tensor(0.9667, grad_fn=<DivBackward0>)
# 188.32
# prediction for price -- tensor(0.9758, grad_fn=<DivBackward0>)
# 188.85
# prediction for price -- tensor(0.9851, grad_fn=<DivBackward0>)
# 187.15
# prediction for price -- tensor(0.9879, grad_fn=<DivBackward0>)
# 187.15
# prediction for price -- tensor(0.9930, grad_fn=<DivBackward0>)
# 187.15
# prediction for price -- tensor(0.9816, grad_fn=<DivBackward0>)
# 185.04
# prediction for price -- tensor(0.9736, grad_fn=<DivBackward0>)
# 184.15
# prediction for price -- tensor(0.9664, grad_fn=<DivBackward0>)
# 183.86
# prediction for price -- tensor(0.9654, grad_fn=<DivBackward0>)
# 182.31
# prediction for price -- tensor(1.0300, grad_fn=<DivBackward0>)
# 181.56
# prediction for price -- tensor(1.0652, grad_fn=<DivBackward0>)
# 181.56
# prediction for price -- tensor(1.0175, grad_fn=<DivBackward0>)
# 181.56
# prediction for price -- tensor(0.9851, grad_fn=<DivBackward0>)
# 181.56
# prediction for price -- tensor(0.9823, grad_fn=<DivBackward0>)
# 182.32
# prediction for price -- tensor(0.9734, grad_fn=<DivBackward0>)
# 184.37
# prediction for price -- tensor(0.9691, grad_fn=<DivBackward0>)
# 182.52
# prediction for price -- tensor(0.9448, grad_fn=<DivBackward0>)
# 181.16
# prediction for price -- tensor(0.9351, grad_fn=<DivBackward0>)
# 181.16
# prediction for price -- tensor(0.9837, grad_fn=<DivBackward0>)
# 181.16
# prediction for price -- tensor(0.9669, grad_fn=<DivBackward0>)
# 182.63
# prediction for price -- tensor(0.9495, grad_fn=<DivBackward0>)
# 181.42
# prediction for price -- tensor(0.9469, grad_fn=<DivBackward0>)
# 180.75
# prediction for price -- tensor(0.9548, grad_fn=<DivBackward0>)
# 179.66
# prediction for price -- tensor(0.9901, grad_fn=<DivBackward0>)
# 175.1
# prediction for price -- tensor(0.9886, grad_fn=<DivBackward0>)
# 175.1
# prediction for price -- tensor(0.9847, grad_fn=<DivBackward0>)
# 175.1
# prediction for price -- tensor(0.9804, grad_fn=<DivBackward0>)
# 170.12
# prediction for price -- tensor(1.0543, grad_fn=<DivBackward0>)
# 169.12
# prediction for price -- tensor(1.0383, grad_fn=<DivBackward0>)
# Progress: [########--] 81.64% 169.0
# prediction for price -- tensor(1.0742, grad_fn=<DivBackward0>)
# 170.73
# prediction for price -- tensor(1.0305, grad_fn=<DivBackward0>)
# 172.75
# prediction for price -- tensor(1.0343, grad_fn=<DivBackward0>)
# 172.75
# prediction for price -- tensor(1.0457, grad_fn=<DivBackward0>)
# 172.75
# prediction for price -- tensor(0.9363, grad_fn=<DivBackward0>)
# 173.23
# prediction for price -- tensor(0.8601, grad_fn=<DivBackward0>)
# 171.13
# prediction for price -- tensor(0.9471, grad_fn=<DivBackward0>)
# 173.0
# prediction for price -- tensor(0.9661, grad_fn=<DivBackward0>)
# 172.62
# prediction for price -- tensor(0.9424, grad_fn=<DivBackward0>)
# 173.72
# prediction for price -- tensor(0.9631, grad_fn=<DivBackward0>)
# 173.72
# prediction for price -- tensor(0.9494, grad_fn=<DivBackward0>)
# 173.72
# prediction for price -- tensor(0.9546, grad_fn=<DivBackward0>)
# 176.08
# prediction for price -- tensor(0.9585, grad_fn=<DivBackward0>)
# 178.67
# prediction for price -- tensor(0.9929, grad_fn=<DivBackward0>)
# 171.37
# prediction for price -- tensor(0.9977, grad_fn=<DivBackward0>)
# 172.28
# prediction for price -- tensor(0.9975, grad_fn=<DivBackward0>)
# 170.85
# prediction for price -- tensor(0.9894, grad_fn=<DivBackward0>)
# 170.85
# prediction for price -- tensor(0.9594, grad_fn=<DivBackward0>)
# 170.85
# prediction for price -- tensor(1.0026, grad_fn=<DivBackward0>)
# 169.71
# prediction for price -- tensor(0.9911, grad_fn=<DivBackward0>)
# 173.31
# prediction for price -- tensor(0.9664, grad_fn=<DivBackward0>)
# 171.48
# prediction for price -- tensor(0.9696, grad_fn=<DivBackward0>)
# 170.03
# prediction for price -- tensor(0.9969, grad_fn=<DivBackward0>)
# 170.03
# prediction for price -- tensor(1.0228, grad_fn=<DivBackward0>)
# 170.03
# prediction for price -- tensor(0.9943, grad_fn=<DivBackward0>)
# 170.03
# prediction for price -- tensor(1.0043, grad_fn=<DivBackward0>)
# 168.84
# prediction for price -- tensor(1.0054, grad_fn=<DivBackward0>)
# 169.65
# prediction for price -- tensor(0.9905, grad_fn=<DivBackward0>)
# 168.82
# prediction for price -- tensor(0.9879, grad_fn=<DivBackward0>)
# 169.58
# prediction for price -- tensor(0.9819, grad_fn=<DivBackward0>)
# 168.45
# prediction for price -- tensor(0.9898, grad_fn=<DivBackward0>)
# 168.45
# prediction for price -- tensor(0.9914, grad_fn=<DivBackward0>)
# 168.45
# prediction for price -- tensor(0.9922, grad_fn=<DivBackward0>)
# 169.67
# prediction for price -- tensor(0.9748, grad_fn=<DivBackward0>)
# 167.78
# prediction for price -- tensor(0.9862, grad_fn=<DivBackward0>)
# 175.04
# prediction for price -- tensor(0.9938, grad_fn=<DivBackward0>)
# 176.55
# prediction for price -- tensor(1.0105, grad_fn=<DivBackward0>)
# 172.69
# prediction for price -- tensor(0.9476, grad_fn=<DivBackward0>)
# 172.69
# prediction for price -- tensor(1.0020, grad_fn=<DivBackward0>)
# 172.69
# prediction for price -- tensor(1.0040, grad_fn=<DivBackward0>)
# 169.38
# prediction for price -- tensor(1.0083, grad_fn=<DivBackward0>)
# 168.0
# prediction for price -- tensor(1.0006, grad_fn=<DivBackward0>)
# 167.04
# prediction for price -- tensor(0.9906, grad_fn=<DivBackward0>)
# 165.0
# prediction for price -- tensor(0.9696, grad_fn=<DivBackward0>)
# 165.84
# prediction for price -- tensor(0.9645, grad_fn=<DivBackward0>)
# 165.84
# prediction for price -- tensor(1.0351, grad_fn=<DivBackward0>)
# 165.84
# prediction for price -- tensor(1.0529, grad_fn=<DivBackward0>)
# 166.9
# prediction for price -- tensor(1.0300, grad_fn=<DivBackward0>)
# 169.02
# prediction for price -- tensor(0.9976, grad_fn=<DivBackward0>)
# 169.89
# prediction for price -- tensor(1.0206, grad_fn=<DivBackward0>)
# 169.3
# prediction for price -- tensor(1.0336, grad_fn=<DivBackward0>)
# 173.5
# prediction for price -- tensor(0.9853, grad_fn=<DivBackward0>)
# 173.5
# prediction for price -- tensor(0.9884, grad_fn=<DivBackward0>)
# 173.5
# prediction for price -- tensor(0.9993, grad_fn=<DivBackward0>)
# 170.33
# prediction for price -- tensor(1.0047, grad_fn=<DivBackward0>)
# 169.3
# prediction for price -- tensor(1.0158, grad_fn=<DivBackward0>)
# 173.03
# prediction for price -- tensor(1.0145, grad_fn=<DivBackward0>)
# 183.38
# prediction for price -- tensor(0.9986, grad_fn=<DivBackward0>)
# 181.71
# prediction for price -- tensor(0.9822, grad_fn=<DivBackward0>)
# 181.71
# prediction for price -- tensor(0.9813, grad_fn=<DivBackward0>)
# 181.71
# prediction for price -- tensor(0.9941, grad_fn=<DivBackward0>)
# 182.4
# prediction for price -- tensor(1.0101, grad_fn=<DivBackward0>)
# 182.74
# prediction for price -- tensor(1.0133, grad_fn=<DivBackward0>)
# 184.57
# prediction for price -- tensor(1.0100, grad_fn=<DivBackward0>)
# 183.05
# prediction for price -- tensor(1.0069, grad_fn=<DivBackward0>)
# 183.05
# prediction for price -- tensor(1.0051, grad_fn=<DivBackward0>)
# Progress: [##########] 100% Done...
#
# Historical Dataframes:
# Account History:
#       AAPL          USD          time  Account Value (USD)
# 0     0.00  10000.00000  1.683945e+09         10000.000000
# 1     0.31   9946.65830  1.683945e+09         10000.000000
# 2     1.14   9803.84020  1.684031e+09         10000.000000
# 3     1.91   9671.34630  1.684117e+09         10000.000000
# 4     3.01   9482.06930  1.684204e+09         10000.000000
# ..     ...          ...           ...                  ...
# 361  22.66   5741.25645  1.715049e+09          9874.440449
# 362  23.49   5589.58225  1.715135e+09          9882.144849
# 363  24.09   5478.84025  1.715221e+09          9925.131549
# 364  24.50   5403.78975  1.715308e+09          9888.514749
# 365  24.80   5348.87475  1.715394e+09          9888.514749
#
# [366 rows x 4 columns]
# Account Returns:
#              time         value
# 0    1.683945e+09           NaN
# 1    1.684031e+09  1.001421e-13
# 2    1.684117e+09 -1.720735e-12
# 3    1.684204e+09  0.000000e+00
# 4    1.684290e+09 -1.720735e-12
# ..            ...           ...
# 360  1.715049e+09  0.000000e+00
# 361  1.715135e+09  1.541071e-03
# 362  1.715221e+09  7.802366e-04
# 363  1.715308e+09  4.349936e-03
# 364  1.715394e+09 -3.689301e-03
#
# [365 rows x 2 columns]
# Resampled Account Value:
#              time         value
# 0    1.683945e+09  10000.000000
# 1    1.684031e+09  10000.000000
# 2    1.684117e+09  10000.000000
# 3    1.684204e+09  10000.000000
# 4    1.684290e+09  10000.000000
# ..            ...           ...
# 360  1.715049e+09   9859.246649
# 361  1.715135e+09   9874.440449
# 362  1.715221e+09   9882.144849
# 363  1.715308e+09   9925.131549
# 364  1.715394e+09   9888.514749
#
# [365 rows x 2 columns]
# Blankly Metrics:
# Calmar Ratio:                      -0.05
# Compound Annual Growth Rate (%):   -1.0%
# Conditional Value-at-Risk:         5.45
# Cumulative Returns (%):            -1.0%
# Max Drawdown (%):                  11.0%
# Resampled Time:                    86400.0
# Risk Free Return Rate:             0.0
# Sharpe Ratio:                      -0.07
# Sortino Ratio:                     -0.08
# Value-at-Risk:                     67.84
# Variance (%):                      0.51%
# Volatility:                        0.07
